# %% [markdown]
# --1番顔認識しずらい仲間を発見しよう--
# 顔認識がしずらいという顔があるのか、顔認識がしずらい私の仲間はどんな表情をすれば顔認識できるのかを調査してみる。

# %%
# %pip install ultralytics dill opencv-python matplotlib facenet-pytorch mtcnn
# 必要なライブラリを一度にインストールします（ノートブック内で実行）。
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (8.3.235)
# Requirement already satisfied: dill in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (0.4.0)
# Requirement already satisfied: opencv-python in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: facenet-pytorch in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (2.5.3)
# Requirement already satisfied: mtcnn in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (0.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: pillow>=7.1.2 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: polars>=0.20.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (1.36.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (7.1.2)
# Requirement already satisfied: numpy>=1.23.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: torch>=1.8.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: keras>=2.0.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from mtcnn) (3.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: absl-py in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from keras>=2.0.0->mtcnn) (2.3.1)
# Requirement already satisfied: namex in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from keras>=2.0.0->mtcnn) (0.1.0)
# Requirement already satisfied: h5py in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from keras>=2.0.0->mtcnn) (3.14.0)
# Requirement already satisfied: rich in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from keras>=2.0.0->mtcnn) (14.2.0)
# Requirement already satisfied: ml-dtypes in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from keras>=2.0.0->mtcnn) (0.5.4)
# Requirement already satisfied: optree in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from keras>=2.0.0->mtcnn) (0.18.0)
# Requirement already satisfied: polars-runtime-32==1.36.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from polars>=0.20.0->ultralytics) (1.36.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: filelock in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: jinja2 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from rich->keras>=2.0.0->mtcnn) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from rich->keras>=2.0.0->mtcnn) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/kanbesouichirou/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.0.0->mtcnn) (0.1.2)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt

# 画像とモデルの準備
image_path = Path("okinawa2.jpg")
model_path = Path("yolov8m-face.pt")

# YOLO で高解像度推論（imgsz を指定）
model = YOLO(model_path)
result = model.predict(source=str(image_path), conf=0.25, verbose=False, imgsz=1280)[0]

# 画像読み込みと基本情報
annotated = cv2.imread(str(image_path))
h_img, w_img = annotated.shape[:2]
color = (0,255,0)
font_scale = 2
thickness = 2

# 検出結果を描画（バッファ付き）
for idx, box in enumerate(result.boxes.xyxy.cpu().numpy()):
    x1,y1,x2,y2 = map(int, box)
    w = x2 - x1; h = y2 - y1
    pad = int(max(w,h) * 0.2)  # バッファ 20%
    x1p = max(0, x1 - pad); y1p = max(0, y1 - pad)
    x2p = min(w_img, x2 + pad); y2p = min(h_img, y2 + pad)
    cv2.rectangle(annotated, (x1p,y1p), (x2p,y2p), color, thickness)
    label = f"ID:{idx}"
    (w_label, h_label), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, font_scale, thickness)
    y_label = y1p-6 if y1p-6>h_label else y1p+h_label+6
    cv2.rectangle(annotated, (x1p, y_label-h_label-baseline), (x1p+w_label, y_label+baseline), color, -1)
    cv2.putText(annotated, label, (x1p, y_label-baseline), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0,0,0), thickness, cv2.LINE_AA)

# 高解像度で保存（アップスケールして保存）
output_path = Path("reitaku_yolo_faces.jpg")
annot_up = cv2.resize(annotated, (w_img*2, h_img*2), interpolation=cv2.INTER_CUBIC)
cv2.imwrite(str(output_path), annot_up)
print(f"検出された顔の数: {len(result.boxes)} faces")
plt.figure(figsize=(16,16))
plt.imshow(cv2.cvtColor(annot_up, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title(f'Reitaku YOLO face × {len(result.boxes)} ')
plt.show()
# Out:
# 検出された顔の数: 14 faces

# %%
import cv2
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt

# 画像とモデルの準備
image_path = Path("okinawa1.jpg")
model_path = Path("yolov8m-face.pt")

# YOLO で高解像度推論（imgsz を指定）
model = YOLO(model_path)
result = model.predict(source=str(image_path), conf=0.25, verbose=False, imgsz=1280)[0]

# 画像読み込みと基本情報
annotated = cv2.imread(str(image_path))
h_img, w_img = annotated.shape[:2]
color = (0,255,0)
font_scale = 2
thickness = 2

# 検出結果を描画（バッファ付き）
for idx, box in enumerate(result.boxes.xyxy.cpu().numpy()):
    x1,y1,x2,y2 = map(int, box)
    w = x2 - x1; h = y2 - y1
    pad = int(max(w,h) * 0.2)  # バッファ 20%
    x1p = max(0, x1 - pad); y1p = max(0, y1 - pad)
    x2p = min(w_img, x2 + pad); y2p = min(h_img, y2 + pad)
    cv2.rectangle(annotated, (x1p,y1p), (x2p,y2p), color, thickness)
    label = f"ID:{idx}"
    (w_label, h_label), baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, font_scale, thickness)
    y_label = y1p-6 if y1p-6>h_label else y1p+h_label+6
    cv2.rectangle(annotated, (x1p, y_label-h_label-baseline), (x1p+w_label, y_label+baseline), color, -1)
    cv2.putText(annotated, label, (x1p, y_label-baseline), cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0,0,0), thickness, cv2.LINE_AA)

# 高解像度で保存（アップスケールして保存）
output_path = Path("reitaku_yolo_faces.jpg")
annot_up = cv2.resize(annotated, (w_img*2, h_img*2), interpolation=cv2.INTER_CUBIC)
cv2.imwrite(str(output_path), annot_up)
print(f"検出された顔の数: {len(result.boxes)} faces")
plt.figure(figsize=(16,16))
plt.imshow(cv2.cvtColor(annot_up, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title(f'Reitaku YOLO face × {len(result.boxes)} ')
plt.show()
# Out:
# 検出された顔の数: 13 faces

# %% [markdown]
# ここで同じメンバーで写真を撮った2つの写真で顔認証したところ、一人だけ顔認証できていない仲間がいることがわかったので、それが誰なのかを分析していく。

# %%
# 切り出した顔のコラージュを高解像度で作成（関数化）：collage_faces(image_path) を定義・実行
import cv2
import numpy as np
from math import ceil
from pathlib import Path
import matplotlib.pyplot as plt

def collage_faces(image_path):
    """
    collage_faces(image_path): YOLO で検出して顔を切り出し、コラージュを作成する関数。
    引数は image_path のみ（文字列または Path）。
    """
    image_path = Path(image_path)
    model_path = Path('yolov8m-face.pt')
    from ultralytics import YOLO
    model = YOLO(model_path)
    result = model.predict(source=str(image_path), conf=0.25, verbose=False, imgsz=1280)[0]

    img = cv2.imread(str(image_path))
    if img is None:
        raise FileNotFoundError(f'Image not found: {image_path}')
    h_img, w_img = img.shape[:2]
    faces = []
    tile = 256

    for box in result.boxes.xyxy.cpu().numpy():
        x1, y1, x2, y2 = map(int, box)
        w = x2 - x1; h = y2 - y1
        pad = int(max(w, h) * 0.2)
        x1p = max(0, x1 - pad); y1p = max(0, y1 - pad)
        x2p = min(w_img, x2 + pad); y2p = min(h_img, y2 + pad)
        if x2p <= x1p or y2p <= y1p:
            continue
        crop = img[y1p:y2p, x1p:x2p]
        h_c, w_c = crop.shape[:2]
        size = max(h_c, w_c)
        square = np.full((size, size, 3), 255, dtype=np.uint8)
        y_off = (size - h_c)//2; x_off = (size - w_c)//2
        square[y_off:y_off+h_c, x_off:x_off+w_c] = crop
        faces.append(cv2.resize(square, (tile, tile), interpolation=cv2.INTER_AREA))

    if len(faces) == 0:
        print('コラージュ用の顔が見つかりません')
        return None

    cols = min(5, len(faces))
    rows = ceil(len(faces) / cols)
    canvas = np.full((rows*tile, cols*tile, 3), 255, dtype=np.uint8)
    for idx, f in enumerate(faces):
        r = idx // cols; c = idx % cols
        canvas[r*tile:(r+1)*tile, c*tile:(c+1)*tile] = f

    output_path = image_path.with_name(image_path.stem + '_faces_collage.jpg')
    cv2.imwrite(str(output_path), canvas)
    print(f'コラージュを保存しました: {output_path} (faces: {len(faces)})')
    plt.figure(figsize=(16,12))
    plt.imshow(cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(f'Faces collage ({len(faces)} faces)')
    plt.show()

# 関数を実行（reitaku.jpg を引数として渡す）
collage_faces('okinawa2.jpg')
# Out:
# コラージュを保存しました: okinawa2_faces_collage.jpg (faces: 14)

# %%
# 切り出した顔のコラージュを高解像度で作成（関数化）：collage_faces(image_path) を定義・実行
import cv2
import numpy as np
from math import ceil
from pathlib import Path
import matplotlib.pyplot as plt

def collage_faces(image_path):
    """
    collage_faces(image_path): YOLO で検出して顔を切り出し、コラージュを作成する関数。
    引数は image_path のみ（文字列または Path）。
    """
    image_path = Path(image_path)
    model_path = Path('yolov8m-face.pt')
    from ultralytics import YOLO
    model = YOLO(model_path)
    result = model.predict(source=str(image_path), conf=0.25, verbose=False, imgsz=1280)[0]

    img = cv2.imread(str(image_path))
    if img is None:
        raise FileNotFoundError(f'Image not found: {image_path}')
    h_img, w_img = img.shape[:2]
    faces = []
    tile = 256

    for box in result.boxes.xyxy.cpu().numpy():
        x1, y1, x2, y2 = map(int, box)
        w = x2 - x1; h = y2 - y1
        pad = int(max(w, h) * 0.2)
        x1p = max(0, x1 - pad); y1p = max(0, y1 - pad)
        x2p = min(w_img, x2 + pad); y2p = min(h_img, y2 + pad)
        if x2p <= x1p or y2p <= y1p:
            continue
        crop = img[y1p:y2p, x1p:x2p]
        h_c, w_c = crop.shape[:2]
        size = max(h_c, w_c)
        square = np.full((size, size, 3), 255, dtype=np.uint8)
        y_off = (size - h_c)//2; x_off = (size - w_c)//2
        square[y_off:y_off+h_c, x_off:x_off+w_c] = crop
        faces.append(cv2.resize(square, (tile, tile), interpolation=cv2.INTER_AREA))

    if len(faces) == 0:
        print('コラージュ用の顔が見つかりません')
        return None

    cols = min(5, len(faces))
    rows = ceil(len(faces) / cols)
    canvas = np.full((rows*tile, cols*tile, 3), 255, dtype=np.uint8)
    for idx, f in enumerate(faces):
        r = idx // cols; c = idx % cols
        canvas[r*tile:(r+1)*tile, c*tile:(c+1)*tile] = f

    output_path = image_path.with_name(image_path.stem + '_faces_collage.jpg')
    cv2.imwrite(str(output_path), canvas)
    print(f'コラージュを保存しました: {output_path} (faces: {len(faces)})')
    plt.figure(figsize=(16,12))
    plt.imshow(cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title(f'Faces collage ({len(faces)} faces)')
    plt.show()

# 関数を実行（reitaku.jpg を引数として渡す）
collage_faces('okinawa1.jpg')
# Out:
# コラージュを保存しました: okinawa1_faces_collage.jpg (faces: 13)

# %% [markdown]
# 分析したところ1枚目の写真の真ん中にいる男が2枚目だは画像認識されていないことがわかった。だが、2枚目の写真を再度確認したところ、彼はそもそも写真に写っていないことがわかった。つまり、同じメンバーで写真を撮っていたという私の記憶が、画像分析によって間違っていたということが判明した。
